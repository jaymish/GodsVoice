# %%
from PIL import Image
import pytesseract
import sys
from pdf2image import convert_from_path,pdfinfo_from_path
import os
import time
import nltk.data
from googletrans import Translator

# %% [markdown]
# Define the input and output file name

# %%
start_time = time.time()
# Path of the pdf
PDF_file = "books/Harry_potter_1.pdf"
# Creating a text file to write the output
outfile = "output_"+str(PDF_file.split(".")[0])+".txt"

# %% [markdown]
# Converting PDF to images

# %%
image_counter = 1
# Counter to store images of each page of PDF to image
info = pdfinfo_from_path(PDF_file, userpw=None, poppler_path=None)

maxPages = info["Pages"]
page_interval=10
for page in range(1, maxPages+1, page_interval) : 
    # Store all the pages of the PDF in a variable
    #pages=convert_from_path(PDF_file, dpi=700, first_page=page, last_page = min(page+page_interval-1,maxPages))
    pages=convert_from_path(PDF_file, dpi=700, first_page=4, last_page = 5)
  
    # Iterate through all the pages stored above
    for page in pages:
      
        #image file name
        filename = str(PDF_file.split(".")[0])+"_page_"+str(image_counter)+".jpg"
          
        # Save the image of the page in system
        page.save(filename, 'JPEG')

        # Increment the counter to update filename
        image_counter = image_counter + 1
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 36.951011180877686 seconds ---

# %% [markdown]
# Reading any language and translating to english using google translate

# %%
# Variable to get count of total number of pages
filelimit = image_counter-1


# Open the file in append mode so that 
# All contents of all images are added to the same file
f = open(outfile, "w",encoding="utf8")
final_txt=''
translator = Translator()  
# Iterate from 1 to total number of pages
for i in range(1, filelimit + 1):
  

    #filename = "page_"+str(i)+".jpg"
    filename = str(PDF_file.split(".")[0])+"_page_"+str(i)+".jpg"
          
    # Recognize the text as string in image using pytesserct
    text = str(((pytesseract.image_to_string(Image.open(filename),lang='san',config=r'--tessdata-dir "C:\Program Files\Tesseract-OCR\tessdata"'))))
  
   
    text = text.replace('-\n', '') 
    text = text.replace('', '') 
    eng_txt=translator.translate(text,dest='en')
    # Finally, write the processed text to the file.
    f.write(eng_txt.text)
    
    #deleting the image files already processed
    os.remove(filename) 
    print(i)
    #print(text)
    final_txt=final_txt+"\n"+text
# Close the file after writing all the text.
f.close()
print(final_txt)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 1
# 2
# 3
# 4
#
#
#
# 56 / स्पर्शं
#
# मेरा जी पढने मेँ बिलकुल न लगता था। एक घंटा भी किताब लेकर बैठना पहाड़ था। मौका पाते
# ही होस्टल से निकलकर मैदान में आ जाता ओर कभी कंकरि्यो उक्ालता, कभी कागज की तितलियां
# उडाता ओर कहीं कोई साथी मिल गया, तो पृना ही क्या। कभी चारदीवारी पर चटढकर नीचे कूद
# रहे है। कभी फाटक पर सवार, उसे आगे-पीछछे चलाते हए मोटरकार का आनंद उठा रहे हे, लेकिन
# कमरे म आते ही भाई साहब का वह रुद्ररूप देखकर प्राण सूख जाते। उनका पहला सवाल यह
# होता-' करटा थे"? हमेशा यही सवाल, इसी ध्वनि में हमेशा पृछा जाता था ओर इसका जवाब मेरे पास
# केवल मौन था। न जाने मेरे मुंह से यह बात क्यों न निकलती कि जरा बाहर खेल रहा था। मेरा मौन
# कह देता था कि मुञ्चे अपना अपराध स्वीकार है ओर भाई साहब के लिए उसके सिवा ओर कोर
# चलाते कि मेरे जिगर के टुकडं-ट॒कडे हो जाते ओर हिम्मत टूट जाती। इस तरह जान तोड़कर मेहनत
# करने की शक्ति मै अपने मंन पाता था ओर उस निराशा मं जरा देर के लिए मेँ सोचने लगता-' क्यों
# न घर चला जाऊं। जो काम मेरे बूते के बाहर हे, उसमे हाथ डालकर क्यों अपनी जिदगी खराब
# करू।' मुदे अपना मूर्ख रहना मंजूर था, लेकिन उतनी मेहनत से मुद्ये तो चक्कर आ जाता था, लेकिन
# घंटे-दो घटे के बाद निराशा के बादल फट जाते ओर मै इरादा करता कि आगे से खूब जी लगाकर
# परदुगा । चटपट एक टाइम-टेबिल बना डालता। बिना पहले से नक्शा बनाए कोई स्कीम तैयार किए
# काम कैसे शुरू करू। टाइम-टेबिल में खेलकूद कौ मद बिलकुल उड जाती। प्रातःकाल छः बजे
# उठना, मंह-हाथ धो, नार्ता कर, पढने बेठ जाना। छः से आठ तक अग्रेजी, आट से नौ तक हिसाब,
#
# 2020-1
#
#
#
# बडे भाई साहब / 57
#
# नो से सादे नो तक इतिहास, फिर भोजन ओर स्कल। सादे तीन बजे स्कूल से वापिस होकर आधा
# घंटा आराम, चार से पांच तक भूगोल, पांच से छः तक ग्रामर, आधा घंटा होस्टल के सामने ही
# टहलना, सादे छः से सात तक अग्रेजी कंपोजीशन, फिर भोजन करके आठ से नौ तक अनुवाद, नौ
# से दस तक हिंदी, दस से ग्यारह तक विविध-विषय, फिर विश्राम।
#
# मगर टाइम-टेविल बना लेना एक बात है, उस पर अमल करना दूसरी बात। पहले ही दिन
# उसकी अवहेलना शुरू हो जाती। मैदान कौ वह सुखद हरियाली, हवा के हलके-हलके ज्ञोके,
# फुटबाल कौ वह उछल- कूद, कबड़ी के वह दाँव-घात, वलीबाल कौ वह तेजी ओर फुरती, मुख
# अज्ञात ओर अनिवार्य रूप से खींच ले जाती ओर वहाँ जाते ही मै सब कुछ भूल जाता। वह जानलेवा
# राइम-रेबिल, वह ओंँखफोड पुस्तके, किसी कौ याद न रहती ओर भाई साहब को नसीहत ओर
# फ़जीहत का अवसर मिल जाता। मँ उनके साये से भागता, उनकी ओखां से दर रहने की चेष्टा करता,
# कमरे मे इस तरह दबे पांव आता कि उन्हं खबर न हो। उनको नजर मेरी ओर उटी ओर मेरे प्राण
# निकले। हमेशा सिर पर एक नंगी तलवार-सी लटकती मालूम होती। फिर भी जैसे मौत ओर विपत्ति
# के बीच भी आदमी मोह ओर माया के बधन में जकडा रहता है, मै फटकार ओर घुडकियोँ खाकर
# भी खेल-कूद का तिरस्कार न कर सकता था।
#
# (2)
#
# सालाना इम्तिहान हआ। भाई साहब फेल हो गए, मेँ पास हो गया ओर दरजे में प्रथम आया। मेरे ओर
# उनके बीच मे केवल दो साल का अतर रह गया। जी मं आया, भाई साहब को आदं हाथां
# लू ` आपकौ वह घोर तपस्या करटा गई? युद्धे देखिए, मजे से खेलता भी रहा ओर दरजे मे अव्वल
# भी हं।' लेकिन वह इतने दुखी ओर उदास थे कि मुद्ध उनसे दिली हमदर्दीं हुई ओर उनके घाव पर
# नमक क्िडकने का विचार ही लज्जास्पद जान पडा। ह, अब मुद्ये अपने ऊपर कु अभिमान हआ
# ओर आत्मसम्मान भी बढा। भाई साहब का वह रोब मुञ्च पर न रहा। आजादी से खेलकूद में शरीक
# होने लगा। दिल मजबूत था। अगर उन्होने फिर मेरी फ़जीहत कौ, तो साफ कह दुंगा- “आपने अपना
# खून जलाकर कोन-सा तीर मार लिया। मै तो खेलते-कूदते दरजे में अव्वल आ गया।' जबान से यह
# हेकटडी जताने का साहस न होने पर भी मेरे रग-ढग से साफ़ जाहिर होता था कि भाई साहब का
# वह आतंक मुञ्च पर नहीं था। भाई साहब ने इसे भप लिया-उनकौ सहज बुद्धि बडी तीव्र थी ओर
# एक दिन जब मैं भोर का सारा समय गुल्ली-डंडे की भैट करके ठीक भोजन के समय लौटा, तो
# भाई साहब ने मानो तलवार खीच ली ओर मुञ्च पर टूट पडे-देखता हूं. इस साल पास हो गए ओर
# द्रजे मेँ अव्वल आ गए, तो तुम्हें दिमाग हो गया हे, मगर भार्दजान, घमंड तो बड़े-बड़े का नहीं रहा,
# तुम्हारी क्या हस्ती है? इतिहास में रावण का हाल तो पठा ही होगा। उसके चरित्र से तुमने कोन-सा
# उपदेश लिया? या योँ ही पद गए? महज इम्तिहान पास कर लेना कोई चीज नहीं, असल चीज है
#
# 2020-1
#
# --- 78.65671992301941 seconds ---

# %%
from googletrans import Translator

translator = Translator()
eng_txt=translator.translate(final_txt,dest='en')
#src='la'
f = open(outfile, "w",encoding="utf8")
f.write(eng_txt.text)
f.close()

# %% [markdown]
# Recognizing text from the images using OCR

# %%
# Variable to get count of total number of pages
filelimit = image_counter-1

# Open the file in append mode so that 
# All contents of all images are added to the same file
f = open(outfile, "w")
  
# Iterate from 1 to total number of pages
for i in range(1, filelimit + 1):
  

    #filename = "page_"+str(i)+".jpg"
    filename = str(PDF_file.split(".")[0])+"_page_"+str(i)+".jpg"
          
    # Recognize the text as string in image using pytesserct
    text = str(((pytesseract.image_to_string(Image.open(filename)))))
  
   
    text = text.replace('-\n', '') 
    text = text.replace('', '') 
  
    # Finally, write the processed text to the file.
    f.write(text)
    
    #deleting the image files already processed
    os.remove(filename) 
  
# Close the file after writing all the text.
f.close()
print("--- %s seconds ---" % (time.time() - start_time))

# %% [markdown]
# Get output as a sentence in a line

# %%
a_file = open(outfile, "r",encoding="ISO-8859-1")
lines = a_file.readlines()
a_file.close()


new_file = open(outfile, "w",encoding="ISO-8859-1")
for line in lines:
    if not (line.startswith('Page |')):
        line=line.replace('\n',' ')
        new_file.write(line)
new_file.close()

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
fp = open(outfile,"r",encoding="ISO-8859-1")
data = fp.read()
fp.close()
text='\n'.join(tokenizer.tokenize(data))
f=open(outfile, "w",encoding="ISO-8859-1")
#print(text)
f.write(text)
f.close()
print("--- %s seconds ---" % (time.time() - start_time))

# %%
import pandas as pd

data = pd.read_fwf(outfile, header = None, delimiter='\n')
print(data)

# %%
pip uninstall googletrans

# %%
pip install googletrans==3.1.0a0
